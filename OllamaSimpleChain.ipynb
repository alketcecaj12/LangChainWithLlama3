# %% [markdown]
# ### This is a simple chain in Ollama

# %%
from langchain.llms import Ollama
from langchain.callbacks.manager import CallbackManager
from langchain.callbacks.streaming_stdout import StreamingStdOutCallbackHandler

# %% [markdown]
# #### Load the model and set the temperature

# %%
llm = Ollama(model="llama3", 
            #  callback_manager = CallbackManager([StreamingStdOutCallbackHandler()]),
            temperature=0.9,
             )

# %% [markdown]
# #### Create a prompt template

# %%
from langchain.prompts import PromptTemplate

prompt = PromptTemplate(
    input_variables=["topic"],
    template="Give me 5 interesting facts about {topic}?",
)

# %% [markdown]
# #### Create a chain

# %%
from langchain.chains import LLMChain
chain = LLMChain(llm=llm, 
                 prompt=prompt,
                 verbose=False)
# Out:
# /var/folders/tt/zbxpsbdn7fd6_zbyqkfm28d40000gn/T/ipykernel_28042/2745389155.py:2: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 1.0. Use RunnableSequence, e.g., `prompt | llm` instead.
#   chain = LLMChain(llm=llm,

# %% [markdown]
# #### Chose a topic from user input

# %%
topic = input()
# Out:
#  medicine

# %% [markdown]
# #### Run the chain

# %%
chain.run(topic)
# Out:
# /var/folders/tt/zbxpsbdn7fd6_zbyqkfm28d40000gn/T/ipykernel_28042/3774777353.py:1: LangChainDeprecationWarning: The method `Chain.run` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use invoke instead.
#   chain.run(topic)
# "Here are 5 interesting facts about medicine:\n\n1. **Antibiotics were discovered by accident**: Penicillin, the first widely used antibiotic, was discovered by Alexander Fleming in 1928. He was studying bacteria when he noticed that one of his cultures had been contaminated with a mold that had killed off the surrounding bacteria. He isolated the substance responsible, penicillin, which has since saved countless lives.\n2. **Aspirin was originally a painkiller for horses**: Aspirin, or acetylsalicylic acid (ASA), was first synthesized in 1899 by German chemist Felix Hoffmann. Initially, it was marketed as a painkiller for horses, not humans. It wasn't until the early 1900s that ASA was approved for human use and became widely prescribed.\n3. **The first vaccine was developed by Edward Jenner**: Jenner, an English physician, developed the first vaccine in 1796 against smallpox. He observed that milkmaids who had contracted cowpox, a similar virus, were immune to smallpox. He tested his theory by inoculating an 8-year-old boy with cowpox, which induced immunity to smallpox. This pioneering work laid the foundation for modern vaccination.\n4. **Insulin was first purified by a team of scientists in 1921**: Canadian researchers Frederick Banting and Charles Best isolated insulin from a dog's pancreas in 1921. They then developed a method to purify the hormone, which led to the first successful treatment of diabetes with insulin injections.\n5. **The first antiseptic was discovered by Louis Pasteur**: In 1865, French scientist Louis Pasteur developed the first antiseptic, carbolic acid (phenol). He observed that the substance prevented the growth of bacteria and reduced infection rates in surgical wounds. This breakthrough led to widespread adoption of antiseptic practices in medicine, revolutionizing the treatment of wounds and reducing mortality rates.\n\nI hope you find these facts interesting!"
